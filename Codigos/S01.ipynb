# %% [markdown]
# # Este es mi primer jupyter noteboook
# ## Econometrics Data Lab
# ## Taller: Introducción a Python

# %% [markdown]
# Este es un código de Python:

# %%
# Operaciones básicas (suma)

25 + 30
# Out:
# 55
